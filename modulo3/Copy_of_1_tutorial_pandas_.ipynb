# %% [markdown]
# <a href="https://colab.research.google.com/github/a01634928/IAA_A01634928/blob/main/modulo3/Copy_of_1_tutorial_pandas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Connect To Google drive
# This will allow this notebook to see your google drive folders.

# %%
from google.colab import drive

drive.mount("/content/gdrive")  
# !pwd  # show current path
# Out:
# Mounted at /content/gdrive
# /content

# %% [markdown]
# Move to the folder where your data set is stored. Change the path to your local drive where the datasets are stored.

# %%
# %cd "/content/gdrive/MyDrive/AaTecM/semestre_7mo/Copia de Notebooks_DataSets_ScripsDB/PrácticasCOLAB"
# !ls  # show current directory
# Out:
# /content/gdrive/.shortcut-targets-by-id/1Pyl02yo9nGqUi3pGKOsHbjvJNkdla9Ek/Notebooks_DataSets_ScripsDB/PrácticasCOLAB
# '1_tutorial numpy.ipynb'	 '3_tutorial seaborn.ipynb'	  iris.names
# '1_tutorial pandas .ipynb'	 '3_tutorial visualizing.ipynb'   wine.data
# '2_tutorial scikit-learn.ipynb'  '4_integration in PCA.ipynb'	  wine.names
# '2_tutorial scipy.ipynb'	  iris.data

# %% [markdown]
# # Load Dataset
#
# dataframe (df) is the object where pandas stores the data, each colum is actualy a hash containing the name of the column a as a key and the array of values as the value for the key. In this example we are loding the iris.data which is a text file that has no headers. So we need to put the header by hand in the names parameter of the read_csv function.

# %%
import pandas as pd

# columns has the name of each column.
columns = ["sepal length","sepal width","petal length","petal width", "class"]
df = pd.read_csv('iris.data',names = columns)
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# you can access the attributes of the dataframe object, for example this is the attribute columns, which has the names of each column in the dataframe.

# %%
df.columns
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width', 'class'], dtype='object')

# %% [markdown]
# You can access a single column as you would a dictionary

# %%
df["sepal length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length, Length: 150, dtype: float64

# %% [markdown]
# you can also get many columns, by providing a list of column names

# %%
df[ ["sepal length","sepal width"] ].head()  # head() returns the first five elements
# Out:
#    sepal length  sepal width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1
# 4           5.0          3.6

# %% [markdown]
# This is how you would separate a data frame into training attributes (predictors, or x) and the target value (class, or y).

# %%
df_x = df[["sepal length","sepal width","petal length","petal width"]]
df_y = df[["class"]]

# %%
df_x
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df_y
# Out:
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %% [markdown]
# Each column of a dataframe is defined a Series object, these objects are built on top of and are very similar to numpy arrays. You can even convert them directly using to_numpy()

# %%
print( type(df_x["sepal length"]))

array = df_x["sepal length"].to_numpy()

print(type(array))

print(array)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'numpy.ndarray'>
# [5.1 4.9 4.7 4.6 5.  5.4 4.6 5.  4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#  5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.
#  5.5 4.9 4.4 5.1 5.  4.5 4.4 5.  5.1 4.8 5.1 4.6 5.3 5.  7.  6.4 6.9 5.5
#  6.5 5.7 6.3 4.9 6.6 5.2 5.  5.9 6.  6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#  6.3 6.1 6.4 6.6 6.8 6.7 6.  5.7 5.5 5.5 5.8 6.  5.4 6.  6.7 6.3 5.6 5.5
#  5.5 6.1 5.8 5.  5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
#  6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.  6.9 5.6 7.7 6.3 6.7 7.2
#  6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.  6.9 6.7 6.9 5.8 6.8
#  6.7 6.7 6.3 6.5 6.2 5.9]

# %% [markdown]
# you can also make new columns with indicators, since dataframes are based on numpy arrays, you can use the numpy operations across full arrays and you can also slice them.

# %%
df_x["sepal proportion"] = df_x["sepal width"]/df_x["sepal length"]
df_x["petal proportion"] = df_x["petal width"]/df_x["petal length"]
df_x.head()
# Out:
#    sepal length  sepal width  petal length  petal width  sepal proportion  \
# 0           5.1          3.5           1.4          0.2          0.686275
# 1           4.9          3.0           1.4          0.2          0.612245
# 2           4.7          3.2           1.3          0.2          0.680851
# 3           4.6          3.1           1.5          0.2          0.673913
# 4           5.0          3.6           1.4          0.2          0.720000
#
#    petal proportion
# 0          0.142857
# 1          0.142857
# 2          0.153846
# 3          0.133333
# 4          0.142857

# %%
df_x["petal proportion"][3:10] # slice from instance 3 to intance 10
# Out:
# 3    0.133333
# 4    0.142857
# 5    0.235294
# 6    0.214286
# 7    0.133333
# 8    0.142857
# 9    0.066667
# Name: petal proportion, dtype: float64

# %% [markdown]
# ### Practice Pandas Loading Data sets.
#
# Open and load the wine data set "wine.data" , it is in the same folder as the iris data set.
#
# Check the names stored in the "wine.names" file to know how to name each column.

# %%
# Specify the names in an list
columns = ["Class","Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium","Total phenols","Flavanoids", "Nonflavanoid phenols","Proanthocyanins","Color intensity","Hue","OD280/OD315 of diluted wines","Proline"]
# Open the file and create the data frame
df = pd.read_csv('wine.data',names = columns)
#df.set_index('')
df.head(-5)
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 168      3    13.58        2.58  2.69               24.5        105
# 169      3    13.40        4.60  2.86               25.0        112
# 170      3    12.20        3.03  2.32               19.0         96
# 171      3    12.77        2.39  2.28               19.5         86
# 172      3    14.16        2.51  2.48               20.0         91
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# 1             2.65        2.76                  0.26             1.28
# 2             2.80        3.24                  0.30             2.81
# 3             3.85        3.49                  0.24             2.18
# 4             2.80        2.69                  0.39             1.82
# ..             ...         ...                   ...              ...
# 168           1.55        0.84                  0.39             1.54
# 169           1.98        0.96                  0.27             1.11
# 170           1.25        0.49                  0.40             0.73
# 171           1.39        0.51                  0.48             0.64
# 172           1.68        0.70                  0.44             1.24
#
#      Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0           5.640000  1.04                          3.92     1065
# 1           4.380000  1.05                          3.40     1050
# 2           5.680000  1.03                          3.17     1185
# 3           7.800000  0.86                          3.45     1480
# 4           4.320000  1.04                          2.93      735
# ..               ...   ...                           ...      ...
# 168         8.660000  0.74                          1.80      750
# 169         8.500000  0.67                          1.92      630
# 170         5.500000  0.66                          1.83      510
# 171         9.899999  0.57                          1.63      470
# 172         9.700000  0.62                          1.71      660
#
# [173 rows x 14 columns]

# %% [markdown]
# Separate the data set into df_x and df_y remeber that the class should be in df_y and everything else in df_x.
#
# print the first five elements of df_x and df_y to check that they are correct.

# %%
# Separate into df_x and df_y
df_x = df[["Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium","Total phenols","Flavanoids", "Nonflavanoid phenols","Proanthocyanins","Color intensity","Hue","OD280/OD315 of diluted wines","Proline"]]
df_y = df[["Class"]]

# Print df_x first 5
df_x

# Print df_y first 5
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
#      Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      OD280/OD315 of diluted wines  Proline
# 0                            3.92     1065
# 1                            3.40     1050
# 2                            3.17     1185
# 3                            3.45     1480
# 4                            2.93      735
# ..                            ...      ...
# 173                          1.74      740
# 174                          1.56      750
# 175                          1.56      835
# 176                          1.62      840
# 177                          1.60      560
#
# [178 rows x 13 columns]

# %%
df_y
# Out:
#      Class
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 173      3
# 174      3
# 175      3
# 176      3
# 177      3
#
# [178 rows x 1 columns]

# %% [markdown]
# Create a new column with a ratio of two attribute, i.e. find to attributes that might have some relation and divide one over the other and store as an extra column in df_x

# %%
# Create new column
df_x["Intense"] = df_x["Alcohol"][0:30]
df_x["Alpro"] = df_x["Alcohol"]/df_x["Proline"]
# Print df_x first 5
df_x
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
#      Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      OD280/OD315 of diluted wines  Proline  Intense     Alpro
# 0                            3.92     1065    14.23  0.013362
# 1                            3.40     1050    13.20  0.012571
# 2                            3.17     1185    13.16  0.011105
# 3                            3.45     1480    14.37  0.009709
# 4                            2.93      735    13.24  0.018014
# ..                            ...      ...      ...       ...
# 173                          1.74      740      NaN  0.018527
# 174                          1.56      750      NaN  0.017867
# 175                          1.56      835      NaN  0.015892
# 176                          1.62      840      NaN  0.015679
# 177                          1.60      560      NaN  0.025232
#
# [178 rows x 15 columns]
